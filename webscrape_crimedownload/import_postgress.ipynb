# %%
import pandas as pd
import glob

# %%
path = r'C:\Users\adfil\downloads'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.head()
# Out:
#            UC2_Literal  Report Number Report Date  \
# 0  LARCENY-NON VEHICLE       90590799  02/28/2009
# 1  LARCENY-NON VEHICLE       90591297  02/28/2009
# 2  LARCENY-NON VEHICLE       90591052  02/28/2009
# 3  LARCENY-NON VEHICLE       90591388  02/28/2009
# 4  LARCENY-NON VEHICLE       90591432  02/28/2009
#
#                       Location  Beat    Neigborhood NPU       Lat      Long  \
# 0                 265 PHARR RD   301     Adair Park   V  33.72710 -84.41360
# 1  265 PEACHTREE CENTER AVE NE   509       Downtown   M  33.76158 -84.38496
# 2         3393 PEACHTREE RD NE   210          Lenox   B  33.84676 -84.36212
# 3       1801 HOWELL MILL RD NW   204  Berkeley Park   D  33.80448 -84.41348
# 4          1275 CAROLINE ST NE   609       Edgewood   O  33.75674 -84.34619
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
frame.to_csv('')
